# %%
from kaggle_environments import make
from IPython.display import display, Image
from langchain_core.messages import AnyMessage, HumanMessage, SystemMessage, AIMessageChunk

# %%
# %load_ext autoreload
# %autoreload 2

import os, sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.domains.environment.environment import Environment

env = Environment()
env.state
# Out:
# SharedRealityState(remainingOverageTime=60, step=0, day=0, hour=0, player=0, farms=[], market=MarketState(inventory=MarketInventory(WHEAT=10000, CARROT=10000, TOMATO=10000, STRAWBERRY=10000, MELON=10000, EGG=10000, MILK=10000, WOOL=10000, FERTILIZER=10000), prices=MarketPrices(WHEAT=25, CARROT=35, TOMATO=60, STRAWBERRY=120, MELON=250, EGG=50, MILK=160, WOOL=200, FERTILIZER=100)), town=TownState(unlocked_shops=[], town_shop_unlock_interval=3, town_shop_sell_interval=4, town_center_sell_interval=12, last_shop_unlock_day=0, last_shop_consume_step=0, last_center_consume_step=0), privates=[])

# %%
env.build(money=200)
env.state
# Out:
# SharedRealityState(remainingOverageTime=60.0, step=0, day=0, hour=0, player=0, farms=[Farm(money=200.0, tiles=[[None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None]], farmer=[5, 5], hands=[], unlocked_quadrants=['NW'], hires_today=0), Farm(money=200.0, tiles=[[None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None]], farmer=[5, 5], hands=[], unlocked_quadrants=['NW'], hires_today=0)], market=Market(inventory=MarketInventory(WHEAT=0, CARROT=0, TOMATO=0, STRAWBERRY=0, MELON=0, EGG=0, MILK=0, WOOL=0, FERTILIZER=0), prices=MarketPrices(WHEAT=1, CARROT=1, TOMATO=1, STRAWBERRY=1, MELON=1, EGG=1, MILK=1, WOOL=1, FERTILIZER=1)), town=Town(unlocked_shops=[], town_shop_unlock_interval=3, town_shop_sell_interval=4, town_center_sell_interval=12, last_shop_unlock_day=0, last_shop_consume_step=0, last_center_consume_step=0), privates=[PrivateState(shed=ShedState(WHEAT=0, CARROT=0, TOMATO=0, STRAWBERRY=0, MELON=0, EGG=0, MILK=0, WOOL=0, FERTILIZER=0, GOOSE=0, COW=0, SHEEP=0), seeds=SeedsState(WHEAT=0, CARROT=0, TOMATO=0, STRAWBERRY=0, MELON=0), inventories=[]), PrivateState(shed=ShedState(WHEAT=0, CARROT=0, TOMATO=0, STRAWBERRY=0, MELON=0, EGG=0, MILK=0, WOOL=0, FERTILIZER=0, GOOSE=0, COW=0, SHEEP=0), seeds=SeedsState(WHEAT=0, CARROT=0, TOMATO=0, STRAWBERRY=0, MELON=0), inventories=[])])

# %%
env.simulate(720)
env.state
# Out:
# SharedRealityState(remainingOverageTime=60.0, step=720, day=30, hour=0, player=1, farms=[Farm(money=0.0, tiles=[[None, None, None, None, None, None, WeedState(kind='WEED'), AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), None, None], [None, None, None, None, AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), WeedState(kind='WEED'), AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), None], [None, AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), None, AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), None, None], [None, AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='PASTURE', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0)], [AnimalState(kind='COOP', animal=None, placed_day=None, yield_units=0, fed_today=False, consecutive_unfed=0, cared_today=False, fertilizer_available=0, pending_care_bonus=0), AnimalState(kind='COOP', animal=None ...

# %%
for a in env.state.privates[0].seeds:
    print(a[0])
# Out:
# WHEAT
# CARROT
# TOMATO
# STRAWBERRY
# MELON
