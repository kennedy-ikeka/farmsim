# %%
# %load_ext autoreload
# %autoreload 2

import os, sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.domains.player.player import Player
from src.models.player import PlayerConfig, ScoreWeights
from src.domains.player.resource import generate_resource_needs, available_resources
from src.domains.player.scoring import apply_action, evaluate_immediate_delta
from src.models.action import ActionState, PassActionState, MoveActionState, BuyAnimalActionState

# %%
plya = Player()
plya.build(money=3000)
# Out:
# Player(remainingOverageTime=60, step=0, day=0, hour=0, player=0, farms=[Farm(money=3000.0, tiles=[[None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None]], farmer=[5, 5], hands=[], unlocked_quadrants=['NW'], hires_today=0)], market=Market(inventory=MarketInventory(WHEAT=0, CARROT=0, TOMATO=0, STRAWBERRY=0, MELON=0, EGG=0, MILK=0, WOOL=0, FERTILIZER=0), prices=MarketPrices(WHEAT=1, CARROT=1, TOMATO=1, STRAWBERRY=1, MELON=1, EGG=1, M
# ...

# %%
pas = PassActionState(type='PASS')
mv = MoveActionState(type='EAST')
buy = BuyAnimalActionState(type='BUY_ANIMAL', animal='COW', count=2)

# %%
apply_action(buy, plya)
# Out:
# Player(remainingOverageTime=60, step=1, day=0, hour=0, player=0, farms=[Farm(money=2200.0, tiles=[[None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None]], farmer=[5, 5], hands=[], unlocked_quadrants=['NW'], hires_today=0)], market=Market(inventory=MarketInventory(WHEAT=0, CARROT=0, TOMATO=0, STRAWBERRY=0, MELON=0, EGG=0, MILK=0, WOOL=0, FERTILIZER=0), prices=MarketPrices(WHEAT=1, CARROT=1, TOMATO=1, STRAWBERRY=1, MELON=1, EGG=1, M
# ...

# %%
evaluate_immediate_delta(mv, plya)
# Out:
# ResourceState(MONEY=0.0, STEP=-1.0, SEED=0.0, LAND=0.0, STRUCTURE=0.0, ANIMAL=0.0, HAND=0.0, PRODUCE=0.0)
