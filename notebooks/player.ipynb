# %%
# %load_ext autoreload
# %autoreload 2

import os, sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.domains.player.player import Player
from src.models.player import PlayerConfig, ScoreWeights
from src.domains.player.scoring import generate_resource_needs

# %%
p = Player()
p.build()
# Out:
# Player(remainingOverageTime=60, step=0, day=0, hour=0, player=0, farms=[Farm(money=0.0, tiles=[[None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None]], farmer=[5, 5], hands=[], unlocked_quadrants=['NW'], hires_today=0)], market=Market(inventory=MarketInventory(WHEAT=0, CARROT=0, TOMATO=0, STRAWBERRY=0, MELON=0, EGG=0, MILK=0, WOOL=0, FERTILIZER=0), prices=MarketPrices(WHEAT=1, CARROT=1, TOMATO=1, STRAWBERRY=1, MELON=1, EGG=1, MILK
# ...

# %%
generate_resource_needs(p)
# Out:
# {'empty_land': 100, 'planted_crops': 0, 'empty_structures': 0, 'placed_animals': 0}
# {'seed_count': 0, 'shed_animals': 0, 'shed_produce': 0}
# ResourceState(MONEY=0, STEP=1.0, SEED=1.0, LAND=0, ANIMAL=0, HAND=0, PRODUCE=0)
